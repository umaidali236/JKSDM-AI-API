# %%
import pandas as pd
import random
from tqdm import tqdm

# %%
self_learning_videos = pd.read_csv('./db/self_learning_courses.csv')

# %%
self_learning_videos['BASIC_ADVANCED'] = ''

# %%
self_learning_videos
# Out:
#                      sector                       name of course
# 0      Aerospace & Aviation                       Aerodynamics_1  \
# 1      Aerospace & Aviation                       Aerodynamics_1
# 2      Aerospace & Aviation                       Aerodynamics_1
# 3      Aerospace & Aviation                       Aerodynamics_1
# 4      Aerospace & Aviation                       Aerodynamics_1
# ...                     ...                                  ...
# 29187        Urban Planning  URBAN TRANSPORTATION AND PLANNING_2
# 29188        Urban Planning  URBAN TRANSPORTATION AND PLANNING_2
# 29189        Urban Planning  URBAN TRANSPORTATION AND PLANNING_2
# 29190        Urban Planning  URBAN TRANSPORTATION AND PLANNING_2
# 29191        Urban Planning  URBAN TRANSPORTATION AND PLANNING_2
#
#                                            module_name
# 0               Module 1: Introduction to Aerodynamics  \
# 1               Module 1: Introduction to Aerodynamics
# ...

# %%
sectors = list(self_learning_videos['sector'].unique())

# %%
map_course_to_basic_advanced = dict()
for sector in tqdm(sectors):
    map_course_to_basic_advanced[sector] =dict()
    print(sector)
    #get courses from a sector
    self_learning_videos_in_a_sector = self_learning_videos[self_learning_videos['sector']==sector]
    courses_in_a_sector = list(self_learning_videos_in_a_sector['name of course'].unique())
    total_courses_in_a_sector= len(courses_in_a_sector)
    if total_courses_in_a_sector < 10:
        some_random_courses_in_a_sector = random.sample(courses_in_a_sector,total_courses_in_a_sector)
    else:
        some_random_courses_in_a_sector = random.sample(courses_in_a_sector,10)
    len_= len(some_random_courses_in_a_sector) #len of sampled courses
    
    for course in courses_in_a_sector:
        
        for c in some_random_courses_in_a_sector[0:len_//2]:
            map_course_to_basic_advanced[sector][c] = 'BASIC'
        for c in some_random_courses_in_a_sector[len_//2:]:
            map_course_to_basic_advanced[sector][c] = 'ADVANCED'
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 258.13it/s]
# Aerospace & Aviation
# Agriculture
# Apparel, Made-Ups & Home Furnishing
# Automotive
# Beauty & Wellness
# BFSI
# Capital Goods
# Construction
# Electronics
# Furniture & Fittings
# Green Jobs
# HealthCare
# IT-ITeS
# Life Sciences
# Logistics
# Management & Entrepreneurship and Professional Skills
# Media and Journalism
# Power and Electrical
# Rubber, Chemical and Petrochemical
# Tourism and Hospitality
# Water Management and Plumbing
# Accounting
# Business Administration
# Chemistry
# Communication
# Economics
# International Relations
# Law
# Marine Engineering
# Marketing
# Mathematics & Statistics
# Mechanical
# Physics
# Political Science
# Public Administration
# Real Estate
# Stenography
# Urban Planning

# %%
map_course_to_basic_advanced['Aerospace & Aviation'].items()
# Out:
# dict_items([('Satellite Communication', 'BASIC'), ('Space Systems Design', 'BASIC'), ('Design of fixed wing Unmanned Aerial Vehicles', 'BASIC'), ('Aircraft Maintenance/Technician', 'BASIC'), ('Aerospace - Advanced Control System Design for Aerospace Vehicles', 'BASIC'), ('Aerodynamics_2', 'ADVANCED'), ('Space Flight Dynamics', 'ADVANCED'), ('Cabin Crew Essentials', 'ADVANCED'), ('Aerodynamics_1', 'ADVANCED'), ('Rocket Propulsion', 'ADVANCED')])

# %%
for e in range(self_learning_videos.shape[0]):
    sector = self_learning_videos['sector'].iloc[e]
    course = self_learning_videos['name of course'].iloc[e]
    if sector in list(map_course_to_basic_advanced.keys()):
        if course in list(map_course_to_basic_advanced[sector].keys()):
            print(sector, course, map_course_to_basic_advanced[sector][course])
            self_learning_videos.at[e, 'BASIC_ADVANCED'] = map_course_to_basic_advanced[sector][course]
# Out:
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# Aerospace & Aviation Aerodynamics_1 ADVANCED
# ...

# %%
self_learning_videos[self_learning_videos['BASIC_ADVANCED']!=''].to_csv('./db/self_learning_courses_basic_advanced.csv',index=None)

# %%
# Out:
#        Unnamed: 0                sector                       name of course
# 0               0  Aerospace & Aviation                       Aerodynamics_1  \
# 1               1  Aerospace & Aviation                       Aerodynamics_1
# 2               2  Aerospace & Aviation                       Aerodynamics_1
# 3               3  Aerospace & Aviation                       Aerodynamics_1
# 4               4  Aerospace & Aviation                       Aerodynamics_1
# ...           ...                   ...                                  ...
# 13059       29147        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
# 13060       29148        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
# 13061       29149        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
# 13062       29150        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
# 13063       29151        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
#
# ...

# %%
#from transformers import BertTokenizer, BertModel
#import torch

# %%
from transformers import BertTokenizer, BertModel
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
model.eval()




def get_bert_embedding(text):
    # Tokenize input text and convert to PyTorch tensors
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    # Get the embeddings for the [CLS] token
    embeddings = outputs.last_hidden_state[:, 0, :].squeeze()
    return embeddings
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
self_learning_courses = dict()
self_learning_courses_embedding_map = dict()

# %%
self_learning_videos = pd.read_csv('./db/self_learning_courses_basic_advanced.csv')

# %%
# Out:
# ['Aerodynamics_1',
#  'Aerodynamics_2',
#  'Aerospace-Introduction to Helicopter Aerodynamics & Dynamics',
#  'Aircraft Maintenance/Technician',
#  'Aviation',
#  'Basic Aeronautical Knowledge',
#  'Cabin Crew Essentials',
#  'Rocket Propulsion',
#  'Introduction to Aircraft Design',
#  'State Space Analysis in Control System and Control Engineering',
#  'Crop Cultivation Essentials',
#  'Crop Production Fundamentals',
#  'Dairy Farmer',
#  'Geographic Information Systems(GIS) in Ag-Essentials and Applications',
#  'Integrated Pest Management (IPM) Essentials',
#  'Organic Farming for Sustainable Agricultural Production',
#  'Soil Testing and Crop Technician',
#  'Garment Construction',
#  'Pattern making classes for beginners',
#  'Sewing Technology (Urdu)',
#  'Sewing Technology',
#  nan,
#  'Automobile Engineering Video Lectures',
#  'AUTOMOTIVE ELECTRONICS',
#  'Automotive Systems Fundamentals',
#  'Electric, Hybrid And Fuel Cell Vehicles',
# ...

# %%
sectors = list(self_learning_videos['sector'].unique())
for sector in tqdm(sectors):
    courses = list(self_learning_videos['name of course'].unique())
    for c in courses:
        if not str(c)=="nan":

            self_learning_courses_embedding_map[c] = get_bert_embedding(c)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 38/38 [10:52<00:00, 17.18s/it]

# %%
embeddings_path=list()
for c in tqdm(list(self_learning_courses_embedding_map.keys())):
    print(c)
    filename = str(c).replace("/","").replace("|","")  
    embeddings_path.append([c,filename+".pt"])
    torch.save(self_learning_courses_embedding_map[c], './db/course_embeddings/'+str(filename)+".pt")
# Out:
#  87%|███████████████████████████████████████████████████████████████████▌          | 266/307 [00:00<00:00, 1302.95it/s]
# Aerodynamics_1
# Aerodynamics_2
# Aerospace-Introduction to Helicopter Aerodynamics & Dynamics
# Aircraft Maintenance/Technician
# Aviation
# Basic Aeronautical Knowledge
# Cabin Crew Essentials
# Rocket Propulsion
# Introduction to Aircraft Design
# State Space Analysis in Control System and Control Engineering
# Crop Cultivation Essentials
# Crop Production Fundamentals
# Dairy Farmer
# Geographic Information Systems(GIS) in Ag-Essentials and Applications
# Integrated Pest Management (IPM) Essentials
# Organic Farming for Sustainable Agricultural Production
# Soil Testing and Crop Technician
# Garment Construction
# Pattern making classes for beginners
# Sewing Technology (Urdu)
# Sewing Technology
# Automobile Engineering Video Lectures
# AUTOMOTIVE ELECTRONICS
# Automotive Systems Fundamentals
# Electric, Hybrid And Fuel Cell Vehicles
# ...

# %%
import pandas as pd
import random
from tqdm import tqdm

# %%
from transformers import BertTokenizer, BertModel
import torch

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
model.eval()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
# ...

# %%
# for i in range(1,len(X.sheet_names)+1):
#     print(i,X.sheet_names[i-1])

# %%
# X.sheet_names

# %%
self_learning_videos = pd.read_csv('./db/self_learning_courses_basic_advanced.csv')

# %%
self_learning_courses_embedding_map = pd.read_csv('./db/embeddings_path.csv')
embeddings_main_path = "./db/course_embeddings/"
self_learning_videos_embeddings = dict()

# %%
self_learning_videos
# Out:
#        Unnamed: 0                sector                       name of course
# 0               0  Aerospace & Aviation                       Aerodynamics_1  \
# 1               1  Aerospace & Aviation                       Aerodynamics_1
# 2               2  Aerospace & Aviation                       Aerodynamics_1
# 3               3  Aerospace & Aviation                       Aerodynamics_1
# 4               4  Aerospace & Aviation                       Aerodynamics_1
# ...           ...                   ...                                  ...
# 13059       29147        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
# 13060       29148        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
# 13061       29149        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
# 13062       29150        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
# 13063       29151        Urban Planning  URBAN TRANSPORTATION AND PLANNING_1
#
# ...

# %%
def get_embeddings_of_self_learning_courses(self_learning_courses_embedding_map, embeddings_main_path, self_learning_videos_embeddings):
    for i in tqdm(range(self_learning_courses_embedding_map.shape[0])):
        course_name = self_learning_courses_embedding_map['name of course'].iloc[i]
        filename = self_learning_courses_embedding_map['embedding_path'].iloc[i]
        #go to the location and fetch it
        #print(embeddings_main_path+str(filename)+".pt")
        self_learning_videos_embeddings[course_name] =  torch.load(embeddings_main_path+str(filename))
    return self_learning_videos_embeddings

# %%
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 307/307 [00:00<00:00, 2423.95it/s]

# %%
def get_bert_embedding(text):
    # Tokenize input text and convert to PyTorch tensors
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    # Get the embeddings for the [CLS] token
    embeddings = outputs.last_hidden_state[:, 0, :].squeeze()
    return embeddings

# %%
self_learning_videos_embeddings[course_name] = get_embeddings_of_self_learning_courses(self_learning_courses_embedding_map, embeddings_main_path, self_learning_videos_embeddings)

# %%
#sectors_and_marks = request.get_json()
sectors_and_marks = {'IT-ITeS':0.5, 'BFSI':0, 'HealthCare':1}

# %%
#sort the keys
sorted_sectors = sorted(sectors_and_marks, key=sectors_and_marks.get, reverse=True)
    

mapping_sector_to_type_of_course = dict()
    

    
for s in sorted_sectors:
    marks_in_sector = sectors_and_marks[s]
    if marks_in_sector >=0.5:
        mapping_sector_to_type_of_course[s] = 'ADVANCED'
    else:
        mapping_sector_to_type_of_course[s] = 'BASIC'
    
    embedding_of_s = get_bert_embedding(s)
    cosine_similarity_of_s_with_all_sectors= dict()

# %%
mapping_sector_to_type_of_course
# Out:
# {'HealthCare': 'ADVANCED', 'IT-ITeS': 'ADVANCED', 'BFSI': 'BASIC'}

# %%
SL_courses_recommended = self_learning_videos[(self_learning_videos['sector']==s) & (self_learning_videos['BASIC_ADVANCED']==mapping_sector_to_type_of_course[s])]

# %%
list_SL_courses_recommended = list(SL_courses_recommended['name of course'].unique())

# %%
# Out:
# ['Finance Theory']

# %%
self_learning_videos[self_learning_videos['name of course']==list_SL_courses_recommended[0]]
# Out:
#       Unnamed: 0 sector  name of course
# 2017        2369   BFSI  Finance Theory  \
# 2018        2370   BFSI  Finance Theory
# 2019        2371   BFSI  Finance Theory
# 2020        2372   BFSI  Finance Theory
# 2021        2373   BFSI  Finance Theory
# 2022        2374   BFSI  Finance Theory
# 2023        2375   BFSI  Finance Theory
# 2024        2376   BFSI  Finance Theory
# 2025        2377   BFSI  Finance Theory
# 2026        2378   BFSI  Finance Theory
# 2027        2379   BFSI  Finance Theory
# 2028        2380   BFSI  Finance Theory
# 2029        2381   BFSI  Finance Theory
# 2030        2382   BFSI  Finance Theory
# 2031        2383   BFSI  Finance Theory
# 2032        2384   BFSI  Finance Theory
# 2033        2385   BFSI  Finance Theory
# 2034        2386   BFSI  Finance Theory
# 2035        2387   BFSI  Finance Theory
# 2036        2388   BFSI  Finance Theory
#
#                                   module_name
# 2017      Module 1: Introduction and Overview  \
# ...

# %%
cosine_similarity_with_sectors= dict()


for self_learning_career_name in list(self_learning_courses_embedding_map.keys()):
    cosine_similarity_with_careers[self_learning_career_name] = torch.nn.functional.cosine_similarity(embedding_of_career_name, self_learning_courses_embedding_map[self_learning_career_name], dim=0)
    
    careers_data_sorted = {k: v for k, v in sorted(cosine_similarity_with_careers.items(), key=lambda x: x[1])}
    careers_data_sorted_list = list(careers_data_sorted.keys())
    CAREERS_DATA_SORTED = dict()
    CAREERS_DATA_SORTED['status'] ='success'
    
    
    
    CAREERS_DATA_SORTED['courses_recommended']= [careers_data_sorted_list[-kkk] for kkk in range(1, int(career_score*10))] 
    CAREERS_DATA_SORTED['courses_links']= [self_learning_courses_links[careers_data_sorted_list[-kkk]] for kkk in range(1, int(career_score*10))]
